# %%
#import packages
from splinter import Browser
from bs4 import BeautifulSoup
import requests
import pandas as pd
import sqlite3

# %%
# url for testing
url = "https://www.akc.org/dog-breeds/golden-retriever/"

# %%
# get response from url
response = requests.get(url)

# %%
# parse html response
soup = BeautifulSoup(response.text, "html.parser")

# %%
# drill into the div element of interest
retreiver = soup.find('div', class_='panel-flex__aside')

# %%
# parse through the list in the div element and strip the correct piece
attributes = []
for list_ in retreiver.ul:
    for attr in list_:
        try:
            attributes.append(attr.text.strip())
        except:
            attributes.append(attr.strip())

# %%
# get rid of empty spaces
attributes  = [a for a in attributes if a is not '']

# %%
# result
print(attributes)
# Out:
# ['Temperament:', 'Friendly, Intelligent, Devoted', 'AKC Breed Popularity:', 'Ranks 3 of 193', 'Height:', '23-24 inches (male), 21.5-22.5 inches (female)', 'Weight:', '65-75 pounds (male), 55-65 pounds (female)', 'Life Expectancy:', '10-12 years', 'Group:', 'Sporting Group', 'The AKC has grouped all of the breeds that it registers into seven categories, or groups, roughly based on function and heritage. Breeds are grouped together because they share traits of form and function or a common heritage.']

# %%
# split up result into keys and values and then turn into dictionary
# all odd values are keys and even values are values
keys = [a for a in attributes if attributes.index(a) % 2 == 0]
values = [a for a in attributes if attributes.index(a) % 2 != 0]
dictionary = dict(zip(keys, values))

# %%
print(dictionary)
# Out:
# {'Temperament:': 'Friendly, Intelligent, Devoted', 'AKC Breed Popularity:': 'Ranks 3 of 193', 'Height:': '23-24 inches (male), 21.5-22.5 inches (female)', 'Weight:': '65-75 pounds (male), 55-65 pounds (female)', 'Life Expectancy:': '10-12 years', 'Group:': 'Sporting Group'}

# %%
# use dictionary to test data cleaning
# data = [dictionary]

# use file extracted by Ryan
data = pd.read_csv('../resources/dirtydatascraped.csv')
# convert dictionary to dataframe
dog_df = pd.DataFrame(data)

# %%
# change index
dog_df[dog_df['Energy level'].str.contains('Brush')]
# Out:
#                          Breed AKC Breed Popularity           Energy level  \
# 71              Dogo Argentino                  NaN  Occasional Bath/Brush
# 108          Karelian Bear Dog                  NaN  Occasional Bath/Brush
# 177  Treeing Tennessee Brindle                  NaN        Weekly Brushing
#
#         Grooming frequency                     Group  \
# 71   Occasional Bath/Brush       Miscellaneous Class
# 108  Occasional Bath/Brush  Foundation Stock Service
# 177        Weekly Brushing  Foundation Stock Service
#
#                                            Height  \
# 71   24-27 inches (male), 23.5-26 inches (female)
# 108                                19-23.5 inches
# 177                                  16-24 inches
#
#                                              Image URL Life Expectancy  \
# 71   https://s3.amazonaws.com/cdn-origin-etr.akc.or...      9-15 years
# 108  https://s3.amazonaws.com/cdn-origin-etr.akc.or...     11-13 years
# 177  https://s3.amazonaws.com/cdn-origin-etr.akc.or...     10-12 years
#
#                    Shedding                     Temperament Trainability  \
# 71   Needs Lots of Activity      Friendly, Cheerful, Humble   Infrequent
# 108                    Calm  Loyal, Independent, Courageous     Seasonal
# 177        Regular Exercise    Friendly, Alert, Intelligent   Occasional
#
#             Weight
# 71   80-100 pounds
# 108   44-49 pounds
# 177   30-50 pounds

# %%
dog_df.at[71, 'Energy level'] = "Calm"
dog_df.at[108, 'Energy level'] = "Energetic"
dog_df.at[177, 'Energy level'] = 'Calm'

# %%
# turn temprament values into referencable array
dog_df['temperament'] = dog_df['Temperament'].str.split(',')

# %%
dog_df['Life Expectancy']
# Out:
# 0         12-15 years
# 1         12-18 years
# 2         11-14 years
# 3         10-13 years
# 4         10-14 years
# 5         11-12 years
# 6         13-15 years
# 7         11-13 years
# 8         12-16 years
# 9         10-14 years
# 10        11-13 years
# 11        12-15 years
# 12        12-16 years
# 13        10-13 years
# 14        12-15 years
# 15        11-15 years
# 16        12-15 years
# 17        12-14 years
# 18        13-14 years
# 19        10-15 years
# 20        12-14 years
# 21        11-16 years
# 22        14-16 years
# 23        12-14 years
# 24        12-14 years
# 25        12-13 years
# 26         7-10 years
# 27        14-15 years
# 28        10-12 years
# 29        10-12 years
#             ...
# 157        8-11 years
# 158          12 years
# 159       12-14 years
# 160       12-14 years
# 161       13-16 years
# 162       10-18 years
# 163       12-14 years
# 164       13-15 years
# 165       12-14 years
# 166    12 to 14 years
# 167       12-14 years
# 168       13-15 years
# 169       12-14 years
# 170       13-16 years
# 171       13-15 years
# 172       12-15 years
# 173       10-12 years
# 174       12-15 years
# 175       15-16 years
# 176       13-15 years
# 177       10-12 years
# 178       12-13 years
# 179       12-14 years
# 180       10-13 years
# 181       12-15 years
# 182       12-15 years
# 183       12-15 years
# 184       12-15 years
# 185       13-18 years
# 186       11-15 years
# Name: Life Expectancy, Length: 187, dtype: object

# %%
# clean data 
dog_df[dog_df['Life Expectancy'].isnull()]
# fill in missing value for Rhodesian Ridgeback
dog_df.at[152, 'Life Expectancy'] = '10-12 years'

# %%
# find bad data
dog_df[dog_df['Life Expectancy'].str.contains('to')]
# fix bad data
dog_df.at[166, 'Life Expectancy'] = '12-14 years'

# %%
# find bad data
dog_df[dog_df['Life Expectancy'].str.contains('Late')]
# fix bad data
dog_df.at[149, 'Life Expectancy'] = '15-17 years'

# %%
dog_df['Life_Expectancy'] = pd.DataFrame(dog_df['Life Expectancy'].str.split(' '))
avg_life_expectancy = []
for index, row in dog_df.iterrows():
    lifespan = row['Life_Expectancy'][0].split('-')

    try:
        avg_life_expectancy.append((int(lifespan[0])+int(lifespan[1])/2))
    except: 
        avg_life_expectancy.append(float(lifespan[0]))
        
#     print(lifespan)
dog_df['avg_life_expectancy'] = avg_life_expectancy
# dog_df['range'] = pd.DataFrame(dog_df['Life_Expectancy'].values.tolist(), index=dog_df.index)
# dog_df.Life_Expectancy.values.tolist()
#

# %%
len(avg_life_expectancy)
# Out:
# 187

# %%
# Debug this for some reason the split(' ') is not working correctly
# might be because the try-except is failing
# cleazn up null values
dog_df[dog_df['Weight'].isnull()]
# Out:
#                  Breed AKC Breed Popularity Energy level Grooming frequency  \
# 13   Australian Kelpie                  NaN    Energetic    Weekly Brushing
# 176    Toy Fox Terrier     Ranks 111 of 193    Energetic    Weekly Brushing
#
#                         Group           Height  \
# 13   Foundation Stock Service     17-20 inches
# 176                 Toy Group  8.5-11.5 inches
#
#                                              Image URL Life Expectancy  \
# 13   https://s3.amazonaws.com/cdn-origin-etr.akc.or...     10-13 years
# 176  https://s3.amazonaws.com/cdn-origin-etr.akc.or...     13-15 years
#
#        Shedding                   Temperament     Trainability Weight  \
# 13    Regularly     Loyal, Alert, Intelligent  Eager to Please    NaN
# 176  Occasional  Friendly, Alert, Intelligent  Eager to Please    NaN
#
#                           temperament Life_Expectancy  avg_life_expectancy
# 13      [Loyal,  Alert,  Intelligent]  [10-13, years]                 16.5
# 176  [Friendly,  Alert,  Intelligent]  [13-15, years]                 20.5

# %%
# insert values into null rows
dog_df.at[13, 'Weight'] = "31-46 pounds (male), 31-46 pounds (female)"
dog_df.at[176, 'Weight'] = "3.5-7 pounds"

# %%
dog_df[dog_df['Weight'].str.contains('under')]
# Out:
#               Breed AKC Breed Popularity      Energy level  \
# 19           Beagle       Ranks 6 of 193         Energetic
# 67        Dachshund      Ranks 12 of 193  Regular Exercise
# 84   French Bulldog       Ranks 4 of 193              Calm
# 120         Maltese      Ranks 37 of 193  Regular Exercise
#
#             Grooming frequency               Group  \
# 19   2-3 Times a Week Brushing         Hound Group
# 67             Weekly Brushing         Hound Group
# 84       Occasional Bath/Brush  Non-Sporting Group
# 120             Daily Brushing           Toy Group
#
#                                             Height  \
# 19                 13 inches & under, 13-15 inches
# 67   8-9 inches (standard), 5-6 inches (miniature)
# 84                                    11-13 inches
# 120                                     7-9 inches
#
#                                              Image URL Life Expectancy  \
# 19   https://s3.amazonaws.com/cdn-origin-etr.akc.or...     10-15 years
# 67   https://s3.amazonaws.com/cdn-origin-etr.akc.or...     12-16 years
# 84   https://s3.amazonaws.com/cdn-origin-etr.akc.or...     10-12 years
# 120  https://s3.amazonaws.com/cdn-origin-etr.akc.or...     12-15 years
#
#        Shedding                Temperament Trainability  \
# 19     Seasonal   Friendly, Curious, Merry    Agreeable
# 67   Occasional  Friendly, Curious, Spunky    Agreeable
# 84    Regularly  Adaptable, Playful, Smart    Agreeable
# 120  Infrequent  Gentle, Playful, Charming    Agreeable
#
#                                                 Weight  \
# 19   under 20 pounds (13 inches & under), 20-30 pou...
# 67   16-32 pounds (standard), 11 pounds & under (mi...
# 84                                     under 28 pounds
# 120                                     under 7 pounds
#
#                        temperament Life_Expectancy  avg_life_expectancy
# 19    [Friendly,  Curious,  Merry]  [10-15, years]                 17.5
# 67   [Friendly,  Curious,  Spunky]  [12-16, years]                 20.0
# 84   [Adaptable,  Playful,  Smart]  [10-12, years]                 16.0
# 120  [Gentle,  Playful,  Charming]  [12-15, years]                 19.5

# %%
dog_df.at[84, 'Weight'] = "28 pounds and under"
dog_df.at[120, 'Weight'] = "7 pounds and under"
dog_df.at[19, 'Weight'] = "22-24 pounds (male), 20-22 pounds (female)"
dog_df.at[97, 'Weight'] = "16-33 pounds"

# %%
dog_df[dog_df['Weight'].str.contains('Proportion')]
# Out:
#          Breed AKC Breed Popularity Energy level     Grooming frequency  \
# 50  Cane Corso      Ranks 32 of 193    Energetic  Occasional Bath/Brush
#
#             Group                                          Height  \
# 50  Working Group  25-27.5 inches (male), 23.5-26 inches (female)
#
#                                             Image URL Life Expectancy  \
# 50  https://s3.amazonaws.com/cdn-origin-etr.akc.or...      9-12 years
#
#       Shedding                          Temperament Trainability  \
# 50  Occasional  Affectionate, Intelligent, Majestic    Agreeable
#
#                      Weight                              temperament  \
# 50  Proportionate to height  [Affectionate,  Intelligent,  Majestic]
#
#    Life_Expectancy  avg_life_expectancy
# 50   [9-12, years]                 15.0

# %%
dog_df.at[50, 'Weight'] = "99-110 pounds (male), 88-99 pounds (female)"

# %%
dog_df[dog_df['Weight'].str.contains('exceeding')]
# Out:
#         Breed AKC Breed Popularity      Energy level     Grooming frequency  \
# 57  Chihuahua      Ranks 33 of 193  Regular Exercise  Occasional Bath/Brush
#
#         Group      Height                                          Image URL  \
# 57  Toy Group  5-8 inches  https://s3.amazonaws.com/cdn-origin-etr.akc.or...
#
#    Life Expectancy    Shedding                Temperament Trainability  \
# 57     14-16 years  Occasional  Charming, Graceful, Sassy  Independent
#
#                     Weight                    temperament Life_Expectancy  \
# 57  not exceeding 6 pounds  [Charming,  Graceful,  Sassy]  [14-16, years]
#
#     avg_life_expectancy
# 57                 22.0

# %%
dog_df.at[57,'Weight'] = '3.3-6.6 pounds'

# %%
dog_df[dog_df['Weight'].str.contains('around')]
# Out:
#              Breed AKC Breed Popularity      Energy level  \
# 164  Silky Terrier     Ranks 112 of 193  Regular Exercise
#
#             Grooming frequency      Group       Height  \
# 164  2-3 Times a Week Brushing  Toy Group  9-10 inches
#
#                                              Image URL Life Expectancy  \
# 164  https://s3.amazonaws.com/cdn-origin-etr.akc.or...     13-15 years
#
#        Shedding                    Temperament Trainability            Weight  \
# 164  Occasional  Friendly, Quick, Keenly Alert    Agreeable  around 10 pounds
#
#                            temperament Life_Expectancy  avg_life_expectancy
# 164  [Friendly,  Quick,  Keenly Alert]  [13-15, years]                 20.5

# %%
dog_df.at[164, 'Weight'] = '10 pounds'

# %%
dog_df[dog_df['Weight'].str.contains('up to')]
# Out:
#                     Breed AKC Breed Popularity Energy level  \
# 137             Pekingese      Ranks 92 of 193         Calm
# 138  Pembroke Welsh Corgi      Ranks 13 of 193    Energetic
#
#             Grooming frequency          Group        Height  \
# 137  2-3 Times a Week Brushing      Toy Group    6-9 inches
# 138            Weekly Brushing  Herding Group  10-12 inches
#
#                                              Image URL Life Expectancy  \
# 137  https://s3.amazonaws.com/cdn-origin-etr.akc.or...     12-14 years
# 138  https://s3.amazonaws.com/cdn-origin-etr.akc.or...     12-13 years
#
#       Shedding                           Temperament     Trainability  \
# 137   Seasonal  Affectionate, Loyal, Regal in Manner  May be Stubborn
# 138  Regularly            Affectionate, Smart, Alert        Agreeable
#
#                                                Weight  \
# 137                                   up to 14 pounds
# 138  up to 30 pounds (male), up to 28 pounds (female)
#
#                                   temperament Life_Expectancy  \
# 137  [Affectionate,  Loyal,  Regal in Manner]  [12-14, years]
# 138            [Affectionate,  Smart,  Alert]  [12-13, years]
#
#      avg_life_expectancy
# 137                 19.0
# 138                 18.5

# %%
dog_df.at[137, 'Weight'] = "14 pounds or less"
dog_df.at[138, 'Weight'] = "30 pounds (male), 28 pounds (female)"

# %%
# split the male and female values into an array
dog_df['Weight2'] = pd.DataFrame(dog_df['Weight'].str.split(','))
avg_wt = []

# for every row, go through and strip out the weight values based on formatting
for index, row in dog_df.iterrows():
    
#     if the last step split things correctly, the first element should be male data
    try: 
        male_weight = row['Weight2'][0]
        male_weight_split = male_weight.split(' ')[0].split('-')
#         print(male_weight_split)
        
#         Sometimes there is only one number for the male and not a range
        try:
            male_avg_weight = (float(male_weight_split[0]) + float(male_weight_split[1]))/2
        except:
            male_avg_weight = float(male_weight_split)
#         print(male_avg_weight) 
#     replace all bad data with zero    
    except:
        male_weight = row['Weight2']
        male_avg_weight = 0
#         print(None)
    
#     if the first step outside loop was successful, the second element should be female data
    try:
        female_weight = row['Weight2'][1]
        female_weight_split = female_weight.split(' ')[0].split('-')
        
#         sometimes the value is just a number and not a range
        try:
            female_avg_weight = (float(female_weight[0]) + float(female_weight[1]))/2
        except:
            female_avg_weight = (float(female_weight))
            
#         if we fail to average the female and male average weights then we just keep the male average
        try:
            avg_weight = (male_avg_weight + female_avg_weight)/2
            avg_wt.append(avg_weight)
        except:
            avg_weight = male_avg_weight
            avg_wt.append(avg_weight)
    
    except:
            avg_weight = male_avg_weight
            avg_wt.append(avg_weight)
            
#     print(avg_wt)
dog_df['avg_weight'] = avg_wt

# %%
dog_df[dog_df['Height'].str.contains('Dogs')]
# Out:
#              Breed AKC Breed Popularity      Energy level Grooming frequency  \
# 112  Kooikerhondje     Ranks 150 of 193  Regular Exercise    Weekly Brushing
#
#               Group                 Height  \
# 112  Sporting Group  Dogs 16", Females 15"
#
#                                              Image URL Life Expectancy  \
# 112  https://s3.amazonaws.com/cdn-origin-etr.akc.or...     12-15 years
#
#      Shedding             Temperament     Trainability       Weight  \
# 112  Seasonal  Friendly, Alert, Quick  Eager to Please  20 - 30 lbs
#
#                     temperament Life_Expectancy  avg_life_expectancy  \
# 112  [Friendly,  Alert,  Quick]  [12-15, years]                 19.5
#
#            Weight2  avg_weight
# 112  [20 - 30 lbs]         0.0

# %%
dog_df.at[112,'Height'] = "16 inches (male), 15 inches (female)"

# %%
dog_df[dog_df['Height'].str.contains('minimum')]
# Out:
#                          Breed AKC Breed Popularity            Energy level  \
# 88   German Wirehaired Pointer      Ranks 63 of 193  Needs Lots of Activity
# 105            Irish Wolfhound      Ranks 76 of 193        Regular Exercise
# 111                   Komondor     Ranks 173 of 193        Regular Exercise
# 173            Tibetan Mastiff     Ranks 131 of 193        Regular Exercise
#
#             Grooming frequency           Group  \
# 88             Weekly Brushing  Sporting Group
# 105            Weekly Brushing     Hound Group
# 111     Specialty/Professional   Working Group
# 173  2-3 Times a Week Brushing   Working Group
#
#                                                 Height  \
# 88     24-26 inches (male), minimum 22 inches (female)
# 105  32 inches minimum (male), 30 inches minimum (f...
# 111  27.5 minimum inches (male), 25.5 minimum inche...
# 173  minimum 26 inches (male), minimum 24 inches (f...
#
#                                              Image URL Life Expectancy  \
# 88   https://s3.amazonaws.com/cdn-origin-etr.akc.or...     14-16 years
# 105  https://s3.amazonaws.com/cdn-origin-etr.akc.or...       6-8 years
# 111  https://s3.amazonaws.com/cdn-origin-etr.akc.or...     10-12 years
# 173  https://s3.amazonaws.com/cdn-origin-etr.akc.or...     10-12 years
#
#                    Shedding                         Temperament  \
# 88                Regularly   Affectionate, Eager, Enthusiastic
# 105                Seasonal         Courageous, Dignified, Calm
# 111  Specialty/Professional             Loyal, Dignified, Brave
# 173                Seasonal  Independent, Reserved, Intelligent
#
#         Trainability                                             Weight  \
# 88   Eager to Please                                       50-70 pounds
# 105      Independent             120 pounds (male), 105 pounds (female)
# 111      Independent  100 pounds or more (male), 80 pounds or more (...
# 173      Independent       90-150 pounds (male), 70-120 pounds (female)
#
#                                 temperament Life_Expectancy  \
# 88    [Affectionate,  Eager,  Enthusiastic]  [14-16, years]
# 105         [Courageous,  Dignified,  Calm]    [6-8, years]
# 111             [Loyal,  Dignified,  Brave]  [10-12, years]
# 173  [Independent,  Reserved,  Intelligent]  [10-12, years]
#
#      avg_life_expectancy                                            Weight2  \
# 88                  22.0                                     [50-70 pounds]
# 105                 10.0          [120 pounds (male),  105 pounds (female)]
# 111                 16.0  [100 pounds or more (male),  80 pounds or more...
# 173                 16.0    [90-150 pounds (male),  70-120 pounds (female)]
#
#      avg_weight
# 88         60.0
# 105         0.0
# 111         0.0
# 173       120.0

# %%
dog_df.at[173, 'Height'] = "26 minimum inches (male), 24 minimum inches (female)"

# %%
# initial split of Height column
dog_df['Height2'] = pd.DataFrame(dog_df['Height'].str.split(','))
avg_ht = []

# loop through all the rows to split up the male height values
for index, row in dog_df.iterrows():
    male_height = row['Height2'][0]
    male_height_split = male_height.split(' ')[0].split('-')
#     print(male_height_split)
#     try to get an average value and if you can't average, just take first value
    try:
        avg_male_height = (float(male_height_split[0]) + float(male_height_split[1]))/2
    except:
        avg_male_height = float(male_height_split[0])

#     print(avg_male_height)
#     try to get a value from the female half and if that fails there wasn't female data
    try:
        female_height = row['Height2'][1]
        female_height_split = female_height.split(' ')[0].split('-')
#     print(male_height_split)
        try:
            avg_female_height = (float(female_height_split[0]) + float(female_height_split[1]))/2
        except:
            avg_female_height = float(female_height_split[0])
        
        try:
            avg_height = (avg_female_height + avg_male_height)/2
            avg_ht.append(avg_height)
        except:
            avg_height = avg_male_height
            avg_ht.append(avg_height)
    
    except:
        avg_height = avg_male_height
        avg_ht.append(avg_height)
# print(avg_ht)
dog_df['avg_height'] = avg_ht

# %%
# select new dataframe with cleaned data and change column names
doggy_df = dog_df[['Breed','Group', 'temperament', 'avg_life_expectancy', 'avg_height', 'avg_weight', 'Energy level', 'Grooming frequency', 'Trainability', 'Shedding']]
doggy_df = doggy_df.rename(columns={'Breed': 'breed','Group':'group', 'avg_life_expectancy': 'life_expectancy_years', 'avg_height': 'avg_height_inch', 'avg_weight': 'avg_weight_pounds', 'Energy level': 'energy', 'Grooming frequency': 'grooming', 'Trainability': 'trainability', 'Shedding': 'shedding'})

# %%
# change index to the breeds
doggy_df.set_index('breed')
# Out:
#                                                    group  \
# breed
# Affenpinscher                                  Toy Group
# Afghan Hound                                 Hound Group
# Airedale Terrier                           Terrier Group
# Akita                                      Working Group
# Alaskan Malamute                           Working Group
# American English Coonhound                   Hound Group
# American Eskimo Dog                   Non-Sporting Group
# American Foxhound                            Hound Group
# American Staffordshire Terrier             Terrier Group
# American Water Spaniel                    Sporting Group
# Anatolian Shepherd Dog                     Working Group
# Appenzeller Sennenhunde         Foundation Stock Service
# Australian Cattle Dog                      Herding Group
# Australian Kelpie               Foundation Stock Service
# Australian Shepherd                        Herding Group
# Australian Terrier                         Terrier Group
# Azawakh                                      Hound Group
# Barbet                               Miscellaneous Class
# Basenji                                      Hound Group
# Beagle                                       Hound Group
# Bearded Collie                             Herding Group
# Bedlington Terrier                         Terrier Group
# Belgian Malinois                           Herding Group
# Belgian Sheepdog                           Herding Group
# Belgian Tervuren                           Herding Group
# Berger Picard                              Herding Group
# Bernese Mountain Dog                       Working Group
# Bichon Frise                          Non-Sporting Group
# Black And Tan Coonhound                      Hound Group
# Black Russian Terrier                      Working Group
# ...                                                  ...
# Scottish Deerhound                           Hound Group
# Scottish Terrier                           Terrier Group
# Sealyham Terrier                           Terrier Group
# Shetland Sheepdog                          Herding Group
# Shiba Inu                             Non-Sporting Group
# Shih Tzu                                       Toy Group
# Siberian Husky                             Working Group
# Silky Terrier                                  Toy Group
# Skye Terrier                               Terrier Group
# Small Munsterlander Pointer     Foundation Stock Service
# Soft Coated Wheaten Terrier                Terrier Group
# Stabyhoun                       Foundation Stock Service
# Staffordshire Bull Terrier                 Terrier Group
# Standard Schnauzer                         Working Group
# Sussex Spaniel                            Sporting Group
# Swedish Vallhund                           Herding Group
# Tibetan Mastiff                            Working Group
# Tibetan Spaniel                       Non-Sporting Group
# Tibetan Terrier                       Non-Sporting Group
# Toy Fox Terrier                                Toy Group
# Treeing Tennessee Brindle       Foundation Stock Service
# Treeing Walker Coonhound                     Hound Group
# Vizsla                                    Sporting Group
# Weimaraner                                Sporting Group
# Welsh Springer Spaniel                    Sporting Group
# Welsh Terrier                              Terrier Group
# Whippet                                      Hound Group
# Wirehaired Pointing Griffon               Sporting Group
# Xoloitzcuintli                        Non-Sporting Group
# Yorkshire Terrier                              Toy Group
#
#                                                                 temperament  \
# breed
# Affenpinscher                       [Confident,  Famously Funny,  Fearless]
# Afghan Hound                                  [Independent,  Sweet,  Regal]
# Airedale Terrier                           [Friendly,  Clever,  Courageous]
